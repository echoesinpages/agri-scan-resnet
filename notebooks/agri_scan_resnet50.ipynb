# %% [markdown]
# # 🌿 Agri-Scan ResNet50 — Training Notebook
# This notebook trains the plant disease classification model.
# Run cells top to bottom. Make sure `kaggle.json` is uploaded to the root directory first.

# %%
# Step 1: Install Kaggle API and configure credentials
import os

# !pip install -q kaggle

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

print('✅ Kaggle setup complete.')

# %%
# Step 2: Make sure we're running from the project root so imports work correctly
import os

# If this notebook is inside /notebooks, move up one level to project root
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')

print(f'Working directory: {os.getcwd()}')

# %%
# Step 3: Run training pipeline
import sys
sys.path.insert(0, 'src')

from train import train_model
history = train_model()

# %%
# Step 4: Plot training history
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'], label='Train Accuracy')
ax1.plot(history.history['val_accuracy'], label='Val Accuracy')
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True)

ax2.plot(history.history['loss'], label='Train Loss')
ax2.plot(history.history['val_loss'], label='Val Loss')
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.savefig('training_history.png', dpi=150)
plt.show()
print('✅ Training plot saved to training_history.png')
