# %% [markdown]
# # 🌿 Exploratory Data Analysis (EDA)
#
# This notebook focuses on inspecting the **New Plant Diseases Dataset** before feeding it into the ResNet50 model.
#
# ### Objectives:
# 1. Visualize sample images from different classes.
# 2. Check the distribution of classes (imbalance check).
# 3. Test image preprocessing steps (resizing/normalization).

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Placeholder for data path
DATA_DIR = '../data/New Plant Diseases Dataset(Augmented)/train'

print("EDA Environment Ready.")

# %% [markdown]
# ### Next Steps
# Run the training script to download the data first, then return here to visualize it.
